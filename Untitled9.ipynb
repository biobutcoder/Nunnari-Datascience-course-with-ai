# %% [markdown]
# <a href="https://colab.research.google.com/github/biobutcoder/Nunnari-Datascience-course-with-ai/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Beginner Exercises
# Date: 13/04/2026

# %% [markdown]
# Variables

# %%
name = "S S Asvanth Kumar"
print(name)
# Out:
# S S Asvanth Kumar

# %%
a=10
b=20
c=a
a=b
b=c
print("a : ",a)
print("b : ",b)
# Out:
# a :  20
# b :  10

# %%
x=1 ; y=2; z=3
print("sum : ",x+y+z)
# Out:
# sum :  6

# %%
var=100
print(var)
var=200
print(var)
# Out:
# 100
# 200

# %%
var=50
del var
print(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10096/1058518712.py in <cell line: 0>()
#       1 var=50
#       2 del var
# ----> 3 print(var)
#
# NameError: name 'var' is not defined

# %% [markdown]
# Data Types

# %%
var1 = 24
print(type(var1))
var2 = 7.1
print(type(var2))
var3 = "hello"
print(type(var3))
var4 = True
print(type(var4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print(type(3.14))
print(type("Hello"))
print(type(True))
print(type(0))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'int'>

# %%
x=9
isinstance(x,int)
# Out:
# True

# %%
print(type(None))
# Out:
# <class 'NoneType'>

# %%
var1 = 237290634602202069504339024529
var2 = float(1/385682095423290485294)
print(var1)
print(var2)
# Out:
# 237290634602202069504339024529
# 2.5928089788624713e-21

# %% [markdown]
# Type Conversion

# %%
string = "123"
integer = int(string)
no = integer + 7
print(no)
# Out:
# 130

# %%
flo = 9.99
no =int(flo)
print(no)
# Out:
# 9

# %%
print(bool(0))
print(bool(1))
# Out:
# False
# True

# %%
print(int(False))
print(int(True))
# Out:
# 0
# 1

# %%
var = int(input("Enter a number : "))
var1 = float(var)
var2 = var1 * 2
print(var2)
# Out:
# Enter a number : 83
# 166.0

# %%
var= "Hello"
var1 = int(var)
print(var1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10096/435216300.py in <cell line: 0>()
#       1 var= "Hello"
# ----> 2 var1 = int(var)
#       3 print(var1)
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %% [markdown]
# String Manipulation

# %%
var = "Hello, World!"
print(var.upper())
print(var.lower())
# Out:
# HELLO, WORLD!
# hello, world!

# %%
var = "Python Programming"
print(len(var))
# Out:
# 18

# %%
var = "Hello, World!"
print(var[6:12:1])
# Out:
#  World

# %%
var = "abcdef"
print(var[::-1])
# Out:
# fedcba

# %%
if "nan" in "banana":
    print("yes")
# Out:
# yes

# %%
var = "This is a bad day"
print(var.replace("bad","good",1))
# Out:
# This is a good day

# %%
var = " hello "
print(var.strip())
# Out:
# hello

# %%
var = "apple,banana,cherry"
print(var.split(","))
# Out:
# ['apple', 'banana', 'cherry']

# %%
b=0
for x in "banana":
  if(x=="a"):
    b=b+1
print(b)
# Out:
# 3

# %%
var = "Python123"
print(var.isalnum())
# Out:
# True

# %% [markdown]
# String Formatting

# %%
name = "John"
age = 25
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is John and I am 25 years old

# %%
price = 49.99
print(f"The price is {price:.2f} dollars")
# Out:
# The price is 49.99 dollars

# %%
pi = 3.14159
print(f"{pi:.2f}")
# Out:
# 3.14

# %%
num = 7
print(f"{num:03d}")
# Out:
# 007

# %%
var1 = 5
var2 = 3
print(f"{var1} * {var2} = {var1*var2}")
# Out:
# 5 * 3 = 15

# %%
students = [("Alice",49),("Benny",74),("Callis",54),("Daniel",92)]
print(f"{'Name':<15} {'Marks':<10}")
print("----------------------")
for Name,Marks in students:
  print(f"{Name:<15} {Marks:<10}")
# Out:
# Name            Marks
# ----------------------
# Alice           49
# Benny           74
# Callis          54
# Daniel          92

# %% [markdown]
# Python Lists

# %%
list1 = ["Mango","Banana","Custard Apple","Lemon",'Grapes']
print(list1)
# Out:
# ['Mango', 'Banana', 'Custard Apple', 'Lemon', 'Grapes']

# %%
list1 = [10, 20, 30, 40, 50]
print(list1[0])
print(list1[-1])
# Out:
# 10
# 50

# %%
list1 = [10, 20, 30, 40, 50]
list1.append(60)
print(list1)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 = [10, 20, 30, 40, 50]
list1.insert(2,99)
print(list1)
# Out:
# [10, 20, 99, 30, 40, 50]

# %%
list1 = ["Mango","Banana","Custard Apple","Lemon",'Grapes']
list1.remove("Banana")
print(list1)
# Out:
# ['Mango', 'Custard Apple', 'Lemon', 'Grapes']

# %%
list1 = [5, 2, 8, 1, 9]
list2 = sorted(list1)
print("Ascending order : ",list2)
list3 = sorted(list1,reverse=True)
print("Descending order : ",list3)
# Out:
# Ascending order :  [1, 2, 5, 8, 9]
# Descending order :  [9, 8, 5, 2, 1]

# %%
list1 = [3, 7, 1, 9, 4]
print("Length : " ,len(list1))
print("Maximum : ",max(list1))
print("Minimum : ",min(list1))
# Out:
# Length :  5
# Maximum :  9
# Minimum :  1

# %%
list1 = [0,1,2,3,4,5,6]
print(list1[2:5])
# Out:
# [2, 3, 4]

# %%
list1 = [0,1,2,3,4,5,6]
list2 = list1.copy()
print("Copied List : ",list2)
list2.append(7)
print("Modifiied the copied list : ",list2)
print("Original list : ",list1)
# Out:
# Copied List :  [0, 1, 2, 3, 4, 5, 6]
# Modifiied the copied list :  [0, 1, 2, 3, 4, 5, 6, 7]
# Original list :  [0, 1, 2, 3, 4, 5, 6]

# %%
list1 = [1,2,3]
list2 = [4,5,6]
list3 = list1 + list2
print("Merged List : ",list3)
# Out:
# Merged List :  [1, 2, 3, 4, 5, 6]
